# %%
from enum import Enum
class FieldType(Enum):
    NONE_FIELD = 0
    ARABLE = 1
    CAGE = 2
    HOUSE = 3
    FENCE = 4

# %%
a= FieldType.NONE_FIELD

# %%
print(a.name)
print(a.value)
# Out:
# NONE_FIELD
# 0

# %%
import random
rand = [1,2,3]
random.shuffle(rand)

# %%
rand
# Out:
# [3, 1, 2]

# %%
class Logger:
    def __init__(self, max_lines=5):
        self.max_lines = max_lines
        self.log_list = []

    def add_log(self, new_message):
        # 새로운 메시지 추가
        self.log_list.append(new_message)
        
        # 로그가 최대 줄 수를 넘으면 가장 오래된 로그 삭제
        if len(self.log_list) > self.max_lines:
            self.log_list.pop(0)
    
    def get_logs(self):
        # 현재 저장된 모든 로그를 하나의 문자열로 반환
        return "\n".join(self.log_list)

# Logger 객체 생성
logger = Logger()

# 로그 함수 테스트
logger.add_log("1")
logger.add_log("2 번째 로그")
logger.add_log("3 번째 로그")
logger.add_log("4 번째 로그")
logger.add_log("5 번째 로그")
logger.add_log("6 번째 로그")

# 저장된 로그 출력
print(logger.get_logs())
# Out:
# 2 번째 로그
# 3 번째 로그
# 4 번째 로그
# 5 번째 로그
# 6 번째 로그

# %%
def gamestart():pass
def move_worker_to_roundcard(player,roundcard_index):
    return True
def move_animal_to_field(animal,filed_index):
    return True
# def ():pass
# def ():pass
# def ():pass
# def ():pass
# def ():pass
# def ():pass
# def ():pass

# %%
gamestart()

# %%
while True:
    if move_worker_to_roundcard(1,1):break

# %%
#양 두마리를 얻었다고 가정

# %%
while True:
    if move_animal_to_field("sheep",1):break

# %%
pip install pydub
# Out:
# Collecting pydubNote: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 24.0 is available.
# You should consider upgrading via the 'c:\Users\js000\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1

# %%
from pydub import AudioSegment

# m4a 파일을 mp3로 변환
audio = AudioSegment.from_file("strongcowsound.m4a", format="m4a")
audio.export("strongcowsound.mp3", format="mp3")
# Out:
# c:\Users\js000\AppData\Local\Programs\Python\Python39\lib\site-packages\pydub\utils.py:198: RuntimeWarning: Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work
#   warn("Couldn't find ffprobe or avprobe - defaulting to ffprobe, but may not work", RuntimeWarning)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 4
#       1 from pydub import AudioSegment
#       3 # m4a 파일을 mp3로 변환
# ----> 4 audio = AudioSegment.from_file("strongcowsound.m4a", format="m4a")
#       5 audio.export("strongcowsound.mp3", format="mp3")
#
# File c:\Users\js000\AppData\Local\Programs\Python\Python39\lib\site-packages\pydub\audio_segment.py:728, in AudioSegment.from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     726     info = None
#     727 else:
# --> 728     info = mediainfo_json(orig_file, read_ahead_limit=read_ahead_limit)
#     729 if info:
#     730     audio_streams = [x for x in info['streams']
#     731                      if x['codec_type'] == 'audio']
#
# File c:\Users\js000\AppData\Local\Programs\Python\Python39\lib\site-packages\pydub\utils.py:274, in mediainfo_json(filepath, read_ahead_limit)
#     271         file.close()
#     273 command = [prober, '-of', 'json'] + command_args
# --> 274 res = Popen(command, stdin=stdin_parameter, stdout=PIPE, stderr=PIPE)
#     275 output, stderr = res.communicate(input=stdin_data)
#     276 output = output.decode("utf-8", 'ignore')
#
# File c:\Users\js000\AppData\Local\Programs\Python\Python39\lib\subprocess.py:951, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     947         if self.text_mode:
#     948             self.stderr = io.TextIOWrapper(self.stderr,
#     949                     encoding=encoding, errors=errors)
# --> 951     self._execute_child(args, executable, preexec_fn, close_fds,
#     952                         pass_fds, cwd, env,
#     953                         startupinfo, creationflags, shell,
#     954                         p2cread, p2cwrite,
#     955                         c2pread, c2pwrite,
#     956                         errread, errwrite,
#     957                         restore_signals,
#     958                         gid, gids, uid, umask,
#     959                         start_new_session)
#     960 except:
#     961     # Cleanup if the child failed starting.
#     962     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File c:\Users\js000\AppData\Local\Programs\Python\Python39\lib\subprocess.py:1420, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1418 # Start the process
#    1419 try:
# -> 1420     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                              # no special security
#    1422                              None, None,
#    1423                              int(not close_fds),
#    1424                              creationflags,
#    1425                              env,
#    1426                              cwd,
#    1427                              startupinfo)
#    1428 finally:
#    1429     # Child is launched. Close the parent's copy of those pipe
#    1430     # handles that only the child should have open.  You need
#    (...)
#    1433     # pipe will not close when the child process exits and the
#    1434     # ReadFile will hang.
#    1435     self._close_pipe_fds(p2cread, p2cwrite,
#    1436                          c2pread, c2pwrite,
#    1437                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다

# %%
pip install PyQt5
# Out:
# Collecting PyQt5
#   Downloading PyQt5-5.15.10-cp37-abi3-macosx_10_13_x86_64.whl.metadata (2.1 kB)
# Collecting PyQt5-sip<13,>=12.13 (from PyQt5)
#   Downloading PyQt5_sip-12.13.0-cp312-cp312-macosx_10_9_universal2.whl.metadata (504 bytes)
# Collecting PyQt5-Qt5>=5.15.2 (from PyQt5)
#   Downloading PyQt5_Qt5-5.15.14-py3-none-macosx_10_13_x86_64.whl.metadata (536 bytes)
# Downloading PyQt5-5.15.10-cp37-abi3-macosx_10_13_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 3.3 MB/s eta 0:00:0000:0100:01
# Downloading PyQt5_Qt5-5.15.14-py3-none-macosx_10_13_x86_64.whl (38.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.8/38.8 MB 3.5 MB/s eta 0:00:0000:0100:01
# Downloading PyQt5_sip-12.13.0-cp312-cp312-macosx_10_9_universal2.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.4/146.4 kB 2.5 MB/s eta 0:00:0000:01
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, PyQt5
# Successfully installed PyQt5-5.15.10 PyQt5-Qt5-5.15.14 PyQt5-sip-12.13.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyInstaller
# Out:
# Collecting PyInstaller
#   Downloading pyinstaller-6.7.0-py3-none-macosx_10_13_universal2.whl.metadata (8.3 kB)
# Collecting setuptools>=42.0.0 (from PyInstaller)
#   Downloading setuptools-70.0.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting altgraph (from PyInstaller)
#   Downloading altgraph-0.17.4-py2.py3-none-any.whl.metadata (7.3 kB)
# Collecting pyinstaller-hooks-contrib>=2024.6 (from PyInstaller)
#   Downloading pyinstaller_hooks_contrib-2024.6-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: packaging>=22.0 in /Users/hoon/Library/Python/3.12/lib/python/site-packages (from PyInstaller) (24.0)
# Collecting macholib>=1.8 (from PyInstaller)
#   Downloading macholib-1.16.3-py2.py3-none-any.whl.metadata (11 kB)
# Downloading pyinstaller-6.7.0-py3-none-macosx_10_13_universal2.whl (960 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.3/960.3 kB 8.2 MB/s eta 0:00:00ta 0:00:01
# Downloading macholib-1.16.3-py2.py3-none-any.whl (38 kB)
# Downloading altgraph-0.17.4-py2.py3-none-any.whl (21 kB)
# Downloading pyinstaller_hooks_contrib-2024.6-py2.py3-none-any.whl (339 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 339.2/339.2 kB 6.6 MB/s eta 0:00:00:00:01
# Downloading setuptools-70.0.0-py3-none-any.whl (863 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.4/863.4 kB 12.1 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: altgraph, setuptools, macholib, pyinstaller-hooks-contrib, PyInstaller
# Successfully installed PyInstaller-6.7.0 altgraph-0.17.4 macholib-1.16.3 pyinstaller-hooks-contrib-2024.6 setuptools-70.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
a = 0

# %%
def p(d):
    d +=1
    return d

# %%
p(a)
# Out:
# 1

# %%
print(a)
# Out:
# 0
